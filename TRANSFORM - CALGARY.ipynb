# %% [markdown]
# **Data EXTRACTION was done manually by downloading the CSV files from municipal open data portals**

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("calgary_business_licences.csv")

# %% [markdown]
# **Drop columns which are not needed.**

# %%
drop_cols = ['COMDISTNM','JOBSTATUSDESC','longitude','latitude','Point']
df = df.drop(drop_cols,axis=1)

# %% [markdown]
# **Rename columns.**

# %%
df = df.rename(columns={'TRADENAME':'Business Name','LICENCETYPES':'Category','JOBCREATED':'Issue Date','ADDRESS': 'Address'})

# %% [markdown]
# **Reorder columns in dataframe. I arbitrarily decided on column ordering based on a gut feeling of what is most intuitive.**

# %%
columns = df.columns
df = df[
    [columns[0],columns[2],columns[3],columns[1]]
]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35715 entries, 0 to 35714
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Business Name  35715 non-null  object
#  1   Category       35715 non-null  object
#  2   Issue Date     35715 non-null  object
#  3   Address        35715 non-null  object
# dtypes: object(4)
# memory usage: 1.1+ MB

# %%
df
# Out:
#                                   Business Name  \
# 0                                      ROOM 210
# 1                               AIKIDO BOZANKAN
# 2                             CAREWELL PHARMACY
# 3                    DUCKTOES COMPUTER SERVICES
# 4                                  CDN CONTROLS
# ...                                         ...
# 35710  ST JAMES CORNER RESTAURANT AND IRISH PUB
# 35711                       OUTER SPACE STORAGE
# 35712                                   EL VAPE
# 35713                    HAIRITAGE STUDIO (THE)
# 35714                              BARBER (THE)
#
#                                                Category  Issue Date  \
# 0                                      PERSONAL SERVICE  2015/09/16
# 1                                      PERSONAL SERVICE  2007/12/05
# 2                              RETAIL DEALER - PREMISES  2017/06/06
# 3                                          MANUFACTURER  2011/01/04
# 4           CONTRACTOR (NO PROVINCIAL LICENCE REQUIRED)  2018/06/04
# ...                                                 ...         ...
# 35710  ALCOHOL BEVERAGE SALES (DRINKING EST/RESTAURANT)  2004/08/20
# 35711                                       WAREHOUSING  2003/10/15
# 35712                          RETAIL DEALER - PREMISES  2021/06/15
# 35713                          RETAIL DEALER - PREMISES  2021/11/03
# 35714                          RETAIL DEALER - PREMISES  2014/10/22
#
#                           Address
# 0                #210 815 1 ST SW
# 1                   7004G 5 ST SE
# 2           #104 580 ACADIA DR SE
# 3                902 CENTRE ST NE
# 4               #1610 311 6 AV SW
# ...                           ...
# 35710                1219 1 ST SW
# 35711         #100 4279 120 AV SE
# 35712                399 17 AV SW
# 35713  #24 20 DOUGLAS WOODS DR SE
# 35714    #4054 356 CRANSTON RD SE
#
# [35715 rows x 4 columns]

# %% [markdown]
# **I chose to include the phone information from the Toronoto dataset. In order to merge all 3 city datasets into 1 unified database, the columns need to be consistent across each table.**

# %% [markdown]
# **Adding the missing columns.**

# %%
df.insert(0,'License Number',np.nan)
df.insert(4,'Expiry Date',np.nan)
df.insert(5,'Phone Number',np.nan)
df.insert(6,'Phone Ext.',np.nan)
df.insert(7,'Phone Type',np.nan)
df.insert(9,'City','Calgary')

# %% [markdown]
# **Modify column dtypes to match their values more appriopriately.**

# %%
df['Expiry Date'] = pd.to_datetime(df['Expiry Date'])
df["Issue Date"] = pd.to_datetime(df["Issue Date"])

# %% [markdown]
# **Observe 'Issue Date' and 'Expiry Date' are now datetime.**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35715 entries, 0 to 35714
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   License Number  0 non-null      float64
#  1   Business Name   35715 non-null  object
#  2   Category        35715 non-null  object
#  3   Issue Date      35715 non-null  datetime64[ns]
#  4   Expiry Date     0 non-null      datetime64[ns]
#  5   Phone Number    0 non-null      float64
#  6   Phone Ext.      0 non-null      float64
#  7   Phone Type      0 non-null      float64
#  8   Address         35715 non-null  object
#  9   City            35715 non-null  object
# dtypes: datetime64[ns](2), float64(4), object(4)
# memory usage: 2.7+ MB

# %%
df
# Out:
#        License Number                             Business Name  \
# 0                 NaN                                  ROOM 210
# 1                 NaN                           AIKIDO BOZANKAN
# 2                 NaN                         CAREWELL PHARMACY
# 3                 NaN                DUCKTOES COMPUTER SERVICES
# 4                 NaN                              CDN CONTROLS
# ...               ...                                       ...
# 35710             NaN  ST JAMES CORNER RESTAURANT AND IRISH PUB
# 35711             NaN                       OUTER SPACE STORAGE
# 35712             NaN                                   EL VAPE
# 35713             NaN                    HAIRITAGE STUDIO (THE)
# 35714             NaN                              BARBER (THE)
#
#                                                Category Issue Date  \
# 0                                      PERSONAL SERVICE 2015-09-16
# 1                                      PERSONAL SERVICE 2007-12-05
# 2                              RETAIL DEALER - PREMISES 2017-06-06
# 3                                          MANUFACTURER 2011-01-04
# 4           CONTRACTOR (NO PROVINCIAL LICENCE REQUIRED) 2018-06-04
# ...                                                 ...        ...
# 35710  ALCOHOL BEVERAGE SALES (DRINKING EST/RESTAURANT) 2004-08-20
# 35711                                       WAREHOUSING 2003-10-15
# 35712                          RETAIL DEALER - PREMISES 2021-06-15
# 35713                          RETAIL DEALER - PREMISES 2021-11-03
# 35714                          RETAIL DEALER - PREMISES 2014-10-22
#
#       Expiry Date  Phone Number  Phone Ext.  Phone Type  \
# 0             NaT           NaN         NaN         NaN
# 1             NaT           NaN         NaN         NaN
# 2             NaT           NaN         NaN         NaN
# 3             NaT           NaN         NaN         NaN
# 4             NaT           NaN         NaN         NaN
# ...           ...           ...         ...         ...
# 35710         NaT           NaN         NaN         NaN
# 35711         NaT           NaN         NaN         NaN
# 35712         NaT           NaN         NaN         NaN
# 35713         NaT           NaN         NaN         NaN
# 35714         NaT           NaN         NaN         NaN
#
#                           Address     City
# 0                #210 815 1 ST SW  Calgary
# 1                   7004G 5 ST SE  Calgary
# 2           #104 580 ACADIA DR SE  Calgary
# 3                902 CENTRE ST NE  Calgary
# 4               #1610 311 6 AV SW  Calgary
# ...                           ...      ...
# 35710                1219 1 ST SW  Calgary
# 35711         #100 4279 120 AV SE  Calgary
# 35712                399 17 AV SW  Calgary
# 35713  #24 20 DOUGLAS WOODS DR SE  Calgary
# 35714    #4054 356 CRANSTON RD SE  Calgary
#
# [35715 rows x 10 columns]

# %%
 df.to_csv('/Users/graemebalint/Documents/Python/Jupyter Notebooks/Canadian Businesses/csv_reformatted/calgary_reformatted.csv',index=False)
